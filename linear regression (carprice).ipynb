# %%
#importing warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd

# %%
carprice=pd.read_csv('C:/Users/Hari/Desktop/place/linear regression assignment/CarPrice_assignment.csv')
carprice.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
carprice=pd.read_csv('C:/Users/Hari/Desktop/place/linear regression assignment/CarPrice_assignment.csv')
pd.options.display.max_rows=None
pd.options.display.max_columns=None
carprice
# Out:
#      car_ID  symboling                          CarName fueltype aspiration  \
# 0         1          3               alfa-romero giulia      gas        std
# 1         2          3              alfa-romero stelvio      gas        std
# 2         3          1         alfa-romero Quadrifoglio      gas        std
# 3         4          2                      audi 100 ls      gas        std
# 4         5          2                       audi 100ls      gas        std
# 5         6          2                         audi fox      gas        std
# 6         7          1                       audi 100ls      gas        std
# 7         8          1                        audi 5000      gas        std
# 8         9          1                        audi 4000      gas      turbo
# 9        10          0              audi 5000s (diesel)      gas      turbo
# 10       11          2                         bmw 320i      gas        std
# ...

# %%
carprice.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 200   sedan        rwd          front      109.1      188.8      68.9
# 201   sedan        rwd          front      109.1      188.8      68.8
# 202   sedan        rwd          front      109.1      188.8      68.9
# 203   sedan        rwd          front      109.1      188.8      68.9
# 204   sedan        rwd          front      109.1      188.8      68.9
#
#      carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# ...

# %%
carprice.shape
# Out:
# (205, 26)

# %%
carprice.size
# Out:
# 5330

# %%
carprice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
carprice.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
#visualizing the data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
carprice.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
# ...

# %%
sns.pairplot(carprice)
plt.show()

# %%
#visualizing the categorical variables
plt.figure(figsize=(20,12))
plt.subplot(2,3,1)
sns.boxplot(x='CarName',y='price',data=carprice)
plt.subplot(2,3,2)
sns.boxplot(x='fueltype',y='price',data=carprice)
plt.subplot(2,3,3)
sns.boxplot(x='aspiration',y='price',data=carprice)
plt.subplot(2,3,4)
sns.boxplot(x='doornumber',y='price',data=carprice)
plt.subplot(2,3,5)
sns.boxplot(x='carbody',y='price',data=carprice)
plt.subplot(2,3,6)
sns.boxplot(x='drivewheel',y='price',data=carprice)
plt.subplot(2,3,2)
sns.boxplot(x='enginelocation',y='price',data=carprice)
plt.subplot(2,3,3)
sns.boxplot(x='enginetype',y='price',data=carprice)
plt.subplot(2,3,4)
sns.boxplot(x='cylindernumber',y='price',data=carprice)
plt.subplot(2,3,5)
sns.boxplot(x='fuelsystem',y='price',data=carprice)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.subplot(1,2,1)
sns.distplot(carprice.price)
plt.subplot(1,2,2)
sns.boxplot(y=carprice.price)
plt.show()

# %%
carprice.price.describe()
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
CompanyName=carprice['CarName'].apply(lambda x : x.split(' ')[0])
carprice.insert(3,"CompanyName",CompanyName)
carprice.drop(['CarName'],axis=1,inplace=True)
carprice.head()
# Out:
#    car_ID  symboling  CompanyName fueltype aspiration doornumber      carbody  \
# 0       1          3  alfa-romero      gas        std        two  convertible
# 1       2          3  alfa-romero      gas        std        two  convertible
# 2       3          1  alfa-romero      gas        std        two    hatchback
# 3       4          2         audi      gas        std       four        sedan
# 4       5          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
# 1        rwd          front       88.6      168.8      64.1       48.8
# 2        rwd          front       94.5      171.2      65.5       52.4
# 3        fwd          front       99.8      176.6      66.2       54.3
# 4        4wd          front       99.4      176.6      66.4       54.3
#
# ...

# %%
carprice.shape
# Out:
# (205, 26)

# %%
carprice.size
# Out:
# 5330

# %%
#unique names in the given companynames
carprice.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
carprice.loc[carprice.duplicated()]
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, CompanyName, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []

# %%
carprice.columns
# Out:
# Index(['car_ID', 'symboling', 'CompanyName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
carprice.head()
# Out:
#    car_ID  symboling  CompanyName fueltype aspiration doornumber      carbody  \
# 0       1          3  alfa-romero      gas        std        two  convertible
# 1       2          3  alfa-romero      gas        std        two  convertible
# 2       3          1  alfa-romero      gas        std        two    hatchback
# 3       4          2         audi      gas        std       four        sedan
# 4       5          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
# 1        rwd          front       88.6      168.8      64.1       48.8
# 2        rwd          front       94.5      171.2      65.5       52.4
# 3        fwd          front       99.8      176.6      66.2       54.3
# 4        4wd          front       99.4      176.6      66.4       54.3
#
# ...

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,3,1)
sns.boxplot(x='CompanyName'  ,y='price',data=carprice)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,12))
plt.subplot(2,3,1)
sns.boxplot(x='carbody',y='carlength',data=carprice)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='fuelsystem',y='price',hue='fueltype',data=carprice)
plt.show()

# %%
plt.figure(figsize=(25,6))
plt.subplot(1,3,1)
plt1=carprice.CompanyName.value_counts().plot(kind='bar')
plt.title('Company Histogram')
plt1.set(xlabel='Car company',ylabel='Frequency of company')
plt.subplot(1,3,2)
plt1=carprice.fueltype.value_counts().plot(kind='bar')
plt.title('fueltype Histogram')
plt1.set(xlabel='fueltype',ylabel='Frequency of fueltype')
plt.subplot(1,3,3)
plt1=carprice.carbody.value_counts().plot(kind='bar')
plt.title('cartype Histogram')
plt1.set(xlabel='cartype',ylabel='Frequency of cartype')
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
sns.countplot(carprice.symboling)
plt.subplot(1,2,2)
sns.boxplot(x=carprice.symboling,y= carprice.price)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,3,1)
sns.countplot(carprice.enginetype)
plt.subplot(1,3,2)
sns.boxplot(x=carprice.enginetype,y= carprice.price)
plt.show()

# %%
plt.figure(figsize=(5,7))
plt.scatter('carlength',1)
plt.scatter('carwidth',2)
plt.scatter('carheight',2.5)
plt.scatter('curbweight',5)
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.title('engine type histogram')
sns.countplot(carprice.enginetype)
plt.subplot(1,2,2)
plt.title('engine type vs price')
sns.boxplot(x=carprice.enginetype,y=carprice.price)
plt.show()
df=pd.DataFrame(carprice.groupby(['enginetype'])['price'].mean().sort_values(ascending=True))
df.plot.bar(figsize=(8,6))
plt.title('engine type vs average price')
plt.show()

# %%
carprice
# Out:
#      car_ID  symboling  CompanyName fueltype aspiration doornumber  \
# 0         1          3  alfa-romero      gas        std        two
# 1         2          3  alfa-romero      gas        std        two
# 2         3          1  alfa-romero      gas        std        two
# 3         4          2         audi      gas        std       four
# 4         5          2         audi      gas        std       four
# 5         6          2         audi      gas        std        two
# 6         7          1         audi      gas        std       four
# 7         8          1         audi      gas        std       four
# 8         9          1         audi      gas      turbo       four
# 9        10          0         audi      gas      turbo        two
# 10       11          2          bmw      gas        std        two
# 11       12          0          bmw      gas        std       four
# 12       13          0          bmw      gas        std        two
# ...

# %%
carprice_lr=carprice[['price','fueltype','aspiration','carbody','drivewheel','wheelbase','curbweight','enginetype','cylindernumber','enginesize','boreratio','horsepower','carlength','carwidth',]]
carprice_lr.head()
# Out:
#      price fueltype aspiration      carbody drivewheel  wheelbase  curbweight  \
# 0  13495.0      gas        std  convertible        rwd       88.6        2548
# 1  16500.0      gas        std  convertible        rwd       88.6        2548
# 2  16500.0      gas        std    hatchback        rwd       94.5        2823
# 3  13950.0      gas        std        sedan        fwd       99.8        2337
# 4  17450.0      gas        std        sedan        4wd       99.4        2824
#
#   enginetype cylindernumber  enginesize  boreratio  horsepower  carlength  \
# 0       dohc           four         130       3.47         111      168.8
# 1       dohc           four         130       3.47         111      168.8
# 2       ohcv            six         152       2.68         154      171.2
# 3        ohc           four         109       3.19         102      176.6
# 4        ohc           five         136       3.19         115      176.6
#
#    carwidth
# 0      64.1
# 1      64.1
# ...

# %%
carprice['fueleconomy']=(0.55*carprice['citympg'])+(0.45*carprice['highwaympg'])
carprice['price']=carprice['price'].astype('int')
temp=carprice.copy()
table=temp.groupby(['CompanyName'])['price'].mean()
temp=temp.merge(table.reset_index(),how='left',on='CompanyName')
bins=[0,10000,20000,40000]
carprice_bin=['budget','medium','highend']
carprice['carsrange']=pd.cut(temp['price_y'],bins,right=False,labels=carprice_bin)
carprice.head()
# Out:
#    car_ID  symboling  CompanyName fueltype aspiration doornumber      carbody  \
# 0       1          3  alfa-romero      gas        std        two  convertible
# 1       2          3  alfa-romero      gas        std        two  convertible
# 2       3          1  alfa-romero      gas        std        two    hatchback
# 3       4          2         audi      gas        std       four        sedan
# 4       5          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
# 1        rwd          front       88.6      168.8      64.1       48.8
# 2        rwd          front       94.5      171.2      65.5       52.4
# 3        fwd          front       99.8      176.6      66.2       54.3
# 4        4wd          front       99.4      176.6      66.4       54.3
#
# ...

# %%
plt.figure(figsize=(8,6))
plt.title('fueleconomy vs price')
sns.scatterplot(x=carprice['fueleconomy'],y=carprice['price'],hue=carprice['drivewheel'])
plt.xlabel('fueleconmy')
plt.ylabel('price')
plt.show()
plt.tight_layout()

# %%
np.corrcoef(carprice['carlength'],carprice['carwidth'])[0,1]
# Out:
# 0.841118268481845

# %%
sns.pairplot(carprice_lr)
plt.show()

# %%
def dummies(x,df):
    temp=pd.get_dummies(df[x],drop_first=True)
    df=pd.concat([df,temp],axis=1)
    df.drop([x],axis=1,inplace=True)
    return df
    carprice_lr=dummies('fueltype',carprice_lr)
    carprice_lr = dummies('aspiration',carprice_lr)
    carprice_lr = dummies('carbody',carprice_lr)
    carprice_lr = dummies('drivewheel',carprice_lr)
    carprice_lr = dummies('enginetype',carprice_lr)
    carprice_lr = dummies('cylindernumber',carprice_lr)
    carprice_lr = dummies('carsrange',carprice_lr)

# %%
 carprice_lr.head()
# Out:
#      price fueltype aspiration      carbody drivewheel  wheelbase  curbweight  \
# 0  13495.0      gas        std  convertible        rwd       88.6        2548
# 1  16500.0      gas        std  convertible        rwd       88.6        2548
# 2  16500.0      gas        std    hatchback        rwd       94.5        2823
# 3  13950.0      gas        std        sedan        fwd       99.8        2337
# 4  17450.0      gas        std        sedan        4wd       99.4        2824
#
#   enginetype cylindernumber  enginesize  boreratio  horsepower  carlength  \
# 0       dohc           four         130       3.47         111      168.8
# 1       dohc           four         130       3.47         111      168.8
# 2       ohcv            six         152       2.68         154      171.2
# 3        ohc           four         109       3.19         102      176.6
# 4        ohc           five         136       3.19         115      176.6
#
#    carwidth
# 0      64.1
# 1      64.1
# ...

# %%
carprice_lr.shape
# Out:
# (205, 14)

# %%
carprice.size
# Out:
# 5740

# %%
#train & test data split

# %%
from sklearn.model_selection import train_test_split
np.random.seed(0)
df_train, df_test = train_test_split(carprice_lr, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
num_vars = ['wheelbase', 'curbweight', 'enginesize', 'boreratio', 'horsepower','carlength','carwidth','price']
df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#         price fueltype aspiration      carbody drivewheel  wheelbase  \
# 122  0.068818      gas        std        sedan        fwd   0.244828
# 125  0.466890      gas        std    hatchback        rwd   0.272414
# 166  0.122110      gas        std    hatchback        rwd   0.272414
# 1    0.314446      gas        std  convertible        rwd   0.068966
# 199  0.382131      gas      turbo        wagon        rwd   0.610345
#
#      curbweight enginetype cylindernumber  enginesize  boreratio  horsepower  \
# 122    0.272692        ohc           four    0.139623   0.230159    0.083333
# 125    0.500388        ohc           four    0.339623   1.000000    0.395833
# 166    0.314973       dohc           four    0.139623   0.444444    0.266667
# 1      0.411171       dohc           four    0.260377   0.626984    0.262500
# 199    0.647401        ohc           four    0.260377   0.746032    0.475000
#
#      carlength  carwidth
# 122   0.426016  0.291667
# 125   0.452033  0.666667
# ...

# %%
df_train.describe()
# Out:
#             price   wheelbase  curbweight  enginesize   boreratio  horsepower  \
# count  143.000000  143.000000  143.000000  143.000000  143.000000  143.000000
# mean     0.219310    0.411141    0.407878    0.241351    0.497946    0.227302
# std      0.215682    0.205581    0.211269    0.154619    0.207140    0.165511
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.067298    0.272414    0.245539    0.135849    0.305556    0.091667
# 50%      0.140343    0.341379    0.355702    0.184906    0.500000    0.191667
# 75%      0.313479    0.503448    0.559542    0.301887    0.682540    0.283333
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         carlength    carwidth
# count  143.000000  143.000000
# mean     0.525476    0.461655
# std      0.204848    0.184517
# min      0.000000    0.000000
# 25%      0.399187    0.304167
# 50%      0.502439    0.425000
# 75%      0.669919    0.550000
# ...

# %%
carprice_lr.head()
# Out:
#      price fueltype aspiration      carbody drivewheel  wheelbase  curbweight  \
# 0  13495.0      gas        std  convertible        rwd       88.6        2548
# 1  16500.0      gas        std  convertible        rwd       88.6        2548
# 2  16500.0      gas        std    hatchback        rwd       94.5        2823
# 3  13950.0      gas        std        sedan        fwd       99.8        2337
# 4  17450.0      gas        std        sedan        4wd       99.4        2824
#
#   enginetype cylindernumber  enginesize  boreratio  horsepower  carlength  \
# 0       dohc           four         130       3.47         111      168.8
# 1       dohc           four         130       3.47         111      168.8
# 2       ohcv            six         152       2.68         154      171.2
# 3        ohc           four         109       3.19         102      176.6
# 4        ohc           five         136       3.19         115      176.6
#
#    carwidth
# 0      64.1
# 1      64.1
# ...

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df_train.corr(),annot=True)
plt.show()

# %%
df_train.head()
# Out:
#         price fueltype aspiration      carbody drivewheel  wheelbase  \
# 122  0.068818      gas        std        sedan        fwd   0.244828
# 125  0.466890      gas        std    hatchback        rwd   0.272414
# 166  0.122110      gas        std    hatchback        rwd   0.272414
# 1    0.314446      gas        std  convertible        rwd   0.068966
# 199  0.382131      gas      turbo        wagon        rwd   0.610345
#
#      curbweight enginetype cylindernumber  enginesize  boreratio  horsepower  \
# 122    0.272692        ohc           four    0.139623   0.230159    0.083333
# 125    0.500388        ohc           four    0.339623   1.000000    0.395833
# 166    0.314973       dohc           four    0.139623   0.444444    0.266667
# 1      0.411171       dohc           four    0.260377   0.626984    0.262500
# 199    0.647401        ohc           four    0.260377   0.746032    0.475000
#
#      carlength  carwidth
# 122   0.426016  0.291667
# 125   0.452033  0.666667
# ...

# %%
df_test.head()
# Out:
#       price fueltype aspiration    carbody drivewheel  wheelbase  curbweight  \
# 160  7738.0      gas        std      sedan        fwd       95.7        2094
# 186  8495.0      gas        std      sedan        fwd       97.3        2275
# 59   8845.0      gas        std  hatchback        fwd       98.8        2385
# 165  9298.0      gas        std      sedan        rwd       94.5        2265
# 140  7603.0      gas        std  hatchback        4wd       93.3        2240
#
#     enginetype cylindernumber  enginesize  boreratio  horsepower  carlength  \
# 160        ohc           four          98       3.19          70      166.3
# 186        ohc           four         109       3.19          85      171.7
# 59         ohc           four         122       3.39          84      177.8
# 165       dohc           four          98       3.24         112      168.7
# 140       ohcf           four         108       3.62          73      157.3
#
#      carwidth
# 160      64.4
# 186      65.5
# ...

# %%
plt.figure(figsize = (16, 10))
sns.heatmap(df_test.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize=[6,6])
plt.scatter(df_train.carlength, df_train.carwidth)
plt.show()

# %%
plt.figure(figsize=[6,6])
sns.boxplot(x=df_train.wheelbase, y=df_train.horsepower)
plt.show()

# %%
plt.figure(figsize=[6,6])
plt.scatter(df_train.carlength, df_train.carlength)
plt.show()

# %%
df_train.head()
# Out:
#         price fueltype aspiration      carbody drivewheel  wheelbase  \
# 122  0.068818      gas        std        sedan        fwd   0.244828
# 125  0.466890      gas        std    hatchback        rwd   0.272414
# 166  0.122110      gas        std    hatchback        rwd   0.272414
# 1    0.314446      gas        std  convertible        rwd   0.068966
# 199  0.382131      gas      turbo        wagon        rwd   0.610345
#
#      curbweight enginetype cylindernumber  enginesize  boreratio  horsepower  \
# 122    0.272692        ohc           four    0.139623   0.230159    0.083333
# 125    0.500388        ohc           four    0.339623   1.000000    0.395833
# 166    0.314973       dohc           four    0.139623   0.444444    0.266667
# 1      0.411171       dohc           four    0.260377   0.626984    0.262500
# 199    0.647401        ohc           four    0.260377   0.746032    0.475000
#
#      carlength  carwidth
# 122   0.426016  0.291667
# 125   0.452033  0.666667
# ...

# %%
y_train = df_train.pop('carlength')
x_train = df_train

# %%
import statsmodels.api as sm

# Add a constant
x_train_lm = sm.add_constant(df_train['horsepower'])

# Create a first fitted model
lr = sm.OLS(y_train, x_train_lm).fit()

# %%
lr.params
# Out:
# const         0.366644
# horsepower    0.698770
# dtype: float64

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              carlength   R-squared:                       0.319
# Model:                            OLS   Adj. R-squared:                  0.314
# Method:                 Least Squares   F-statistic:                     65.98
# Date:                Sun, 26 Apr 2020   Prob (F-statistic):           2.07e-13
# Time:                        09:02:05   Log-Likelihood:                 51.763
# No. Observations:                 143   AIC:                            -99.53
# Df Residuals:                     141   BIC:                            -93.60
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3666      0.024     15.176      0.000       0.319       0.414
# ...

# %%
#adding another variable
X_train_lm = df_train[['wheelbase', 'curbweight']]

# %%
import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train_lm)

lr = sm.OLS(y_train, X_train_lm).fit()

lr.params
# Out:
# const         0.130523
# wheelbase     0.480308
# curbweight    0.484161
# dtype: float64

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              carlength   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     442.2
# Date:                Sun, 26 Apr 2020   Prob (F-statistic):           3.13e-61
# Time:                        09:02:14   Log-Likelihood:                 166.62
# No. Observations:                 143   AIC:                            -327.2
# Df Residuals:                     140   BIC:                            -318.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1305      0.015      8.848      0.000       0.101       0.160
# ...

# %%
x_train_lm = x_train[['wheelbase', 'curbweight','enginesize']]

# %%
import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train_lm)

lr = sm.OLS(y_train, X_train_lm).fit()

lr.params
# Out:
# const         0.130523
# wheelbase     0.480308
# curbweight    0.484161
# dtype: float64

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              carlength   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     442.2
# Date:                Sun, 26 Apr 2020   Prob (F-statistic):           3.13e-61
# Time:                        09:02:20   Log-Likelihood:                 166.62
# No. Observations:                 143   AIC:                            -327.2
# Df Residuals:                     140   BIC:                            -318.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1305      0.015      8.848      0.000       0.101       0.160
# ...

# %%
carprice_lr.columns
# Out:
# Index(['price', 'fueltype', 'aspiration', 'carbody', 'drivewheel', 'wheelbase',
#        'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio',
#        'horsepower', 'carlength', 'carwidth'],
#       dtype='object')

# %%
import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train_lm)

lr1 = sm.OLS(y_train, x_train_lm).fit()

lr1.params
# Out:
# wheelbase     0.618439
# curbweight    0.644116
# enginesize   -0.066006
# dtype: float64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x_train.head()
# Out:
#         price fueltype aspiration      carbody drivewheel  wheelbase  \
# 122  0.068818      gas        std        sedan        fwd   0.244828
# 125  0.466890      gas        std    hatchback        rwd   0.272414
# 166  0.122110      gas        std    hatchback        rwd   0.272414
# 1    0.314446      gas        std  convertible        rwd   0.068966
# 199  0.382131      gas      turbo        wagon        rwd   0.610345
#
#      curbweight enginetype cylindernumber  enginesize  boreratio  horsepower  \
# 122    0.272692        ohc           four    0.139623   0.230159    0.083333
# 125    0.500388        ohc           four    0.339623   1.000000    0.395833
# 166    0.314973       dohc           four    0.139623   0.444444    0.266667
# 1      0.411171       dohc           four    0.260377   0.626984    0.262500
# 199    0.647401        ohc           four    0.260377   0.746032    0.475000
#
#      carwidth
# 122  0.291667
# 125  0.666667
# 166  0.308333
# 1    0.316667
# ...

# %%
carprice_lr.head()
# Out:
#      price fueltype aspiration      carbody drivewheel  wheelbase  curbweight  \
# 0  13495.0      gas        std  convertible        rwd       88.6        2548
# 1  16500.0      gas        std  convertible        rwd       88.6        2548
# 2  16500.0      gas        std    hatchback        rwd       94.5        2823
# 3  13950.0      gas        std        sedan        fwd       99.8        2337
# 4  17450.0      gas        std        sedan        4wd       99.4        2824
#
#   enginetype cylindernumber  enginesize  boreratio  horsepower  carlength  \
# 0       dohc           four         130       3.47         111      168.8
# 1       dohc           four         130       3.47         111      168.8
# 2       ohcv            six         152       2.68         154      171.2
# 3        ohc           four         109       3.19         102      176.6
# 4        ohc           five         136       3.19         115      176.6
#
#    carwidth
# 0      64.1
# 1      64.1
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def build_model(X,y):
    #Adding the constant
    X = sm.add_constant(X)
    # fitting the model
    lm = sm.OLS(y,X).fit()
     # model summary
    print(lm.summary())
    return X
    
def checkVIF(X):
    vif = pd.DataFrame()
    vif['Features'] = X.columns
    vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif['VIF'] = round(vif['VIF'], 2)
    vif = vif.sort_values(by = "VIF", ascending = False)
    return(vif)

# %%
x_train_new = build_model(x_train_lm,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              carlength   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     294.5
# Date:                Sun, 26 Apr 2020   Prob (F-statistic):           5.11e-60
# Time:                        09:02:35   Log-Likelihood:                 167.01
# No. Observations:                 143   AIC:                            -326.0
# Df Residuals:                     139   BIC:                            -314.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1307      0.015      8.850      0.000       0.101       0.160
# ...

# %%
checkVIF(x_train_lm)
# Out:
#      Features    VIF
# 1  curbweight  36.32
# 2  enginesize  15.27
# 0   wheelbase  13.51

# %%
x_train_lm1 = x_train[['price','wheelbase','curbweight','enginesize','carwidth','boreratio','horsepower']]
x_train_lm1.head()
# Out:
#         price  wheelbase  curbweight  enginesize  carwidth  boreratio  \
# 122  0.068818   0.244828    0.272692    0.139623  0.291667   0.230159
# 125  0.466890   0.272414    0.500388    0.339623  0.666667   1.000000
# 166  0.122110   0.272414    0.314973    0.139623  0.308333   0.444444
# 1    0.314446   0.068966    0.411171    0.260377  0.316667   0.626984
# 199  0.382131   0.610345    0.647401    0.260377  0.575000   0.746032
#
#      horsepower
# 122    0.083333
# 125    0.395833
# 166    0.266667
# 1      0.262500
# 199    0.475000

# %%
import statsmodels.api as sm
x_train_lm1 = sm.add_constant(x_train_lm1)

lr = sm.OLS(y_train, x_train_lm1).fit()

lr.params
# Out:
# const         0.073779
# price        -0.078000
# wheelbase     0.421863
# curbweight    0.444500
# enginesize   -0.041731
# carwidth      0.149799
# boreratio     0.113677
# horsepower   -0.007181
# dtype: float64

# %%
def checkVIF(X):
    vif = pd.DataFrame()
    vif['Features'] = X.columns
    vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif['VIF'] = round(vif['VIF'], 2)
    vif = vif.sort_values(by = "VIF", ascending = False)
    return(vif)

# %%
x_train_new = build_model(x_train_lm1,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              carlength   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.871
# Method:                 Least Squares   F-statistic:                     137.9
# Date:                Sun, 26 Apr 2020   Prob (F-statistic):           2.78e-58
# Time:                        09:31:35   Log-Likelihood:                 174.31
# No. Observations:                 143   AIC:                            -332.6
# Df Residuals:                     135   BIC:                            -308.9
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0738      0.022      3.395      0.001       0.031       0.117
# ...

# %%
checkVIF(x_train_lm1)
# Out:
#      Features    VIF
# 0       const  12.47
# 3  curbweight  11.32
# 4  enginesize   5.97
# 1       price   5.79
# 5    carwidth   5.66
# 2   wheelbase   4.99
# 7  horsepower   4.83
# 6   boreratio   1.68

# %%
lm1 = sm.OLS(y_train,x_train_lm).fit()
y_train_price = lm.predict(x_train_lm1)

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_price), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  
plt.xlabel('Errors', fontsize = 18)
# Out:
# Text(0.5, 0, 'Errors')
